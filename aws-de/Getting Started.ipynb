# %%
print('We in here.')
# Out:
# We in here.

# %%
import boto3

# %%
s3_client = boto3.client('s3')

# %%
type(s3_client)
# Out:
# botocore.client.S3

# %%
buckets = s3_client.list_buckets()['Buckets']

# %%
bucket = buckets[0]

# %%
bucket
# Out:
# {'Name': 'awsglueudemycourse-marcmaurice-gluejob2-source',
#  'CreationDate': datetime.datetime(2023, 6, 13, 19, 29, 41, tzinfo=tzutc())}

# %%
bucket['Name']
# Out:
# 'awsglueudemycourse-marcmaurice-gluejob2-source'

# %%
bucket_names = [bucket['Name'] for bucket in buckets]

# %%
bucket_name
# Out:
# ['awsglueudemycourse-marcmaurice-gluejob2-source',
#  'cf-templates-1xhu63d7vhsyh-us-east-1',
#  'cf-templates-1xhu63d7vhsyh-us-east-2',
#  'databricks-workspace-stack-1795d-bucket',
#  'databricks-workspace-stack-385f1-bucket',
#  'elasticbeanstalk-us-east-2-796757800855',
#  'marc-snowflake-data1',
#  'marcmytempfiles',
#  'marcyoutubedataanalysis',
#  'marcyoutubedataanalysis-cleansed',
#  'mydataforbloom',
#  'snowflakecomputingpro1',
#  'snowflakedatapipelinepro1']
